# %%
import pandas as pd
import numpy as np
import requests
import gmaps
# Import the API key.
from config import g_key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# import citipy

from citipy import citipy

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['kahului',
#  'ostrovnoy',
#  'new norfolk',
#  'punta arenas',
#  'albany',
#  'labuhan',
#  'saldanha',
#  'rikitea',
#  'mataura',
#  'nuevo ideal',
#  'kaitangata',
#  'cape town',
#  'castro',
#  'codrington',
#  'kruisfontein',
#  'westport',
#  'hobart',
#  'hilo',
#  'san quintin',
#  'baran',
#  'burns lake',
#  'palabuhanratu',
#  'tonj',
#  'talcahuano',
#  'bambous virieux',
#  'guerrero negro',
#  'vila franca do campo',
#  'ust-kuyga',
#  'butaritari',
#  'port elizabeth',
#  'jamestown',
#  'bredasdorp',
#  'severo-kurilsk',
#  'kapaa',
#  'puerto ayora',
#  'bethel',
#  'nkayi',
#  'biltine',
#  'shingu',
#  'saskylakh',
#  'bluff',
#  'grand river south east',
#  'iqaluit',
#  'addis zemen',
#  'inhambane',
#  'pevek',
#  'busselton',
#  'tekeli',
#  'chicama',
#  'airai',
#  'vaini',
#  'mozarlandia',
#  'verkhnechusovskiye gorodki',
#  'nikolskoye',
#  'matara',
#  'selfoss',
#  'fare',
#  'warqla',
#  'xining',
#  'miraflores',
#  'ushuaia',
#  'saleaula',
#  'chokurdakh',
#  'saint-leu',
#  'san cristobal',
#  'port alfred',
#  'taolanaro',
#  'komsomolskiy',
#  'bara',
#  'alofi',
#  'baghdad',
#  'dali',
#  'batticaloa',
#  'loa janan',
#  'faanui',
#  'daru',
#  'wanaka',
#  'posadas',
#  'belushya guba',
#  'amderma',
#  'bollnas',
#  'arraial do cabo',
#  'aklavik',
#  'jumla',
#  'thompson',
#  'luancheng',
#  'narsaq',
#  'kingaroy',
#  'georgetown',
#  'portland',
#  'caravelas',
#  'tasiilaq',
#  'tuktoyaktuk',
#  'mago',
#  'taoudenni',
#  'nanchang',
#  'vaitupu',
#  'vila velha',
#  'ombessa',
#  'chara',
#  'avarua',
#  'vestmanna',
#  'tucumcari',
#  'illoqqortoormiut',
#  'segou',
#  'leningradskiy',
#  'pisco',
#  'tuatapere',
#  'provideniya',
#  'kodiak',
#  'qaanaaq',
#  'lyuban',
#  'cabo san lucas',
#  'petropavlovsk-kamchatskiy',
#  'luganville',
#  'college',
#  'saint-philippe',
#  'paradwip',
#  'quatre cocos',
#  'atuona',
#  'iskateley',
#  'suntar',
#  'jardim',
#  'bamberg',
#  'owando',
#  'sentyabrskiy',
#  'kamwenge',
#  'aswan',
#  'marcona',
#  'nizhneyansk',
#  'carnarvon',
#  'sakakah',
#  'port lincoln',
#  'mahajanga',
#  'tsihombe',
#  'barrow',
#  'barentsburg',
#  'brandon',
#  'namwala',
#  'henties bay',
#  'ribeira grande',
#  'balabac',
#  'rohru',
#  'monrovia',
#  'machilipatnam',
#  'vardo',
#  'khatanga',
#  'hermanus',
#  'americus',
#  'rocha',
#  'leshukonskoye',
#  'mpongwe',
#  'la rioja',
#  'viedma',
#  'loknya',
#  'kuche',
#  'barkhan',
#  'northam',
#  'nanortalik',
#  'porterville',
#  'povenets',
#  'husavik',
#  'cayenne',
#  'tungor',
#  'fenoarivo',
#  'nome',
#  'marsabit',
#  'turukhansk',
#  'fort nelson',
#  'tabiauea',
#  'rognan',
#  'vredendal',
#  'lebu',
#  'constantine',
#  'bourail',
#  'mar del plata',
#  'buraydah',
#  'ayolas',
#  'aksu',
#  'vaitape',
#  'maunabo',
#  'makoshyne',
#  'ahuimanu',
#  'ponta do sol',
#  'sambava',
#  'lasa',
#  'dubbo',
#  'surman',
#  'aykhal',
#  'sitio novo do tocantins',
#  'yellowknife',
#  'morant bay',
#  'upernavik',
#  'diu',
#  'norman wells',
#  'marsh harbour',
#  'santiago del estero',
#  'srednekolymsk',
#  'makung',
#  'olafsvik',
#  'znamenskoye',
#  'rio grande',
#  'dudinka',
#  'sao joao da barra',
#  'hithadhoo',
#  'dunedin',
#  'coquimbo',
#  'saint simons',
#  'torbay',
#  'hofn',
#  'bengkulu',
#  'ha tinh',
#  'prince rupert',
#  'lavrentiya',
#  'angoram',
#  'daura',
#  'zapolyarnyy',
#  'sitka',
#  'bereda',
#  'isangel',
#  'souillac',
#  'formosa',
#  'leninsk',
#  'esperance',
#  'nioro',
#  'porto torres',
#  'ulverstone',
#  'zhurivka',
#  'rawson',
#  'geraldton',
#  'leh',
#  'belaya gora',
#  'alta floresta',
#  'brae',
#  'waingapu',
#  'krasnoarmeysk',
#  'toliary',
#  'elverum',
#  'ancud',
#  'othonoi',
#  'erice',
#  'andros town',
#  'palmer',
#  'saint george',
#  'tautira',
#  'kununurra',
#  'dimitrovgrad',
#  'saint-joseph',
#  'yatou',
#  'umzimvubu',
#  'courtalam',
#  'kavieng',
#  'tumannyy',
#  'fairbanks',
#  'skalistyy',
#  'batagay-alyta',
#  'nabire',
#  'coihaique',
#  'yantal',
#  'pangnirtung',
#  'inuvik',
#  'vestmannaeyjar',
#  'ngunguru',
#  'korla',
#  'mercedes',
#  'kyabram',
#  'blagoyevo',
#  'verkhnyaya inta',
#  'isabela',
#  'roscrea',
#  'chachapoyas',
#  'novyy yarychiv',
#  'ballinasloe',
#  'lewistown',
#  'samusu',
#  'ciudad bolivar',
#  'bargal',
#  'bartica',
#  'hervey bay',
#  'cidreira',
#  'manaure',
#  'scottsburgh',
#  'eyl',
#  'dikson',
#  'muros',
#  'key west',
#  'atar',
#  'huarmey',
#  'savelugu',
#  'vanimo',
#  'sola',
#  'aporawan',
#  'barstow',
#  'victoria',
#  'kapit',
#  'east london',
#  'izberbash',
#  'sechura',
#  'pacific grove',
#  'puerto escondido',
#  'kinkala',
#  'teeli',
#  'port hardy',
#  'cukai',
#  'presidente medici',
#  'ketchikan',
#  'tiksi',
#  'great bend',
#  'kachug',
#  'ozernovskiy',
#  'mys shmidta',
#  'faya',
#  'halifax',
#  'sobolevo',
#  'chaohu',
#  'placido de castro',
#  'seara',
#  'bud',
#  'necochea',
#  'chuy',
#  'lompoc',
#  'shagonar',
#  'chany',
#  'kathu',
#  'san rafael',
#  'teluknaga',
#  'ansalta',
#  'khorixas',
#  'matagami',
#  'anadyr',
#  'ayan',
#  'nizwa',
#  'sao filipe',
#  'cangucu',
#  'gravelbourg',
#  'ngukurr',
#  'grindavik',
#  'dibulla',
#  'concepcion',
#  'cherskiy',
#  'flinders',
#  'bagotville',
#  'grand centre',
#  'naze',
#  'galiwinku',
#  'port hedland',
#  'werda',
#  'luderitz',
#  'ranot',
#  'bonoua',
#  'yumen',
#  'nishihara',
#  'hammerfest',
#  'champerico',
#  'san patricio',
#  'iranshahr',
#  'dolores',
#  'kachiry',
#  'anastacio',
#  'tomball',
#  'ziduri',
#  'bontang',
#  'longyearbyen',
#  'payo',
#  'vao',
#  'east stroudsburg',
#  'saint-francois',
#  'kangaatsiaq',
#  'mnogovershinnyy',
#  'bonfim',
#  'masunga',
#  'jalu',
#  'barela',
#  'harper',
#  'samalaeulu',
#  'fort saint john',
#  'ca mau',
#  'gobabis',
#  'el faiyum',
#  'tezu',
#  'louisbourg',
#  'coahuayana',
#  'cabra',
#  'najran',
#  'sagua la grande',
#  'matozinhos',
#  'ulaanbaatar',
#  'humboldt',
#  'ginda',
#  'price',
#  'baza',
#  'sept-iles',
#  'beloha',
#  'lensk',
#  'flin flon',
#  'libohove',
#  'adrar',
#  'lorengau',
#  'juneau',
#  'clyde river',
#  'mana',
#  'zhuzhou',
#  'puro',
#  'honningsvag',
#  'antofagasta',
#  'port macquarie',
#  'kichera',
#  'hohhot',
#  'hasaki',
#  'awjilah',
#  'udachnyy',
#  'chifeng',
#  'turan',
#  'chiang klang',
#  'cajnice',
#  'mersing',
#  'nkan',
#  'burnie',
#  'svetlyy',
#  'darhan',
#  'kamenskoye',
#  'maragogi',
#  'kontagora',
#  'upington',
#  'kabinda',
#  'eureka',
#  'tevaitoa',
#  'attawapiskat',
#  'lowestoft',
#  'san carlos de bariloche',
#  'nyrob',
#  'port-gentil',
#  'buala',
#  'yanan',
#  'ye',
#  'yuancheng',
#  'ostrogozhsk',
#  'yendi',
#  'fortuna',
#  'zhangjiakou',
#  'haukipudas',
#  'bujaru',
#  'kulhudhuffushi',
#  'wahran',
#  'san antonio',
#  'jurm',
#  'uhlove',
#  'igis',
#  'borgo san lorenzo',
#  'denpasar',
#  'mbandaka',
#  'puerto carreno',
#  'broken hill',
#  'barra do pirai',
#  'hamilton',
#  'venado tuerto',
#  'burgeo',
#  'tuban',
#  'los alamos',
#  'manakara',
#  'magrath',
#  'jaciara',
#  'la asuncion',
#  'hovd',
#  'laguna',
#  'puerto lempira',
#  'uvat',
#  'ponta delgada',
#  'wakkanai',
#  'samarai',
#  'bathsheba',
#  'omsukchan',
#  'berezna',
#  'bubaque',
#  'belawan',
#  'takoradi',
#  'nokha',
#  'raniganj',
#  'pokhara',
#  'voh',
#  'gorom-gorom',
#  'rawannawi',
#  'chikoy',
#  'sibolga',
#  'tamluk',
#  'skibbereen',
#  'figeac',
#  'cervo',
#  'rudbar',
#  'roma',
#  'hokitika',
#  'frederick',
#  'port hawkesbury',
#  'haines junction',
#  'lagunas',
#  'tasbuget',
#  'saint marys',
#  'la estancia',
#  'opuwo',
#  'coruripe',
#  'nampula',
#  'maniitsoq',
#  'shache',
#  'beyneu',
#  'bacuit',
#  'ranong',
#  'segamat',
#  'myanaung',
#  'tuzha',
#  'brigantine',
#  'rodez',
#  'muscat',
#  'wahiawa',
#  'caloundra',
#  'mareeba',
#  'rungata',
#  'praia',
#  'alice springs',
#  'acapulco',
#  'rancho mirage',
#  'ordynskoye',
#  'jiddah',
#  'san isidro',
#  'san narciso',
#  'kazalinsk',
#  'meadow lake',
#  'kota kinabalu',
#  'ilebo',
#  'salalah',
#  'mocambique',
#  'rio branco',
#  'bolkhov',
#  'kidal',
#  'korsakov',
#  'aflu',
#  'knin',
#  'sao luis do quitunde',
#  'bay roberts',
#  'mayo',
#  'havoysund',
#  'itainopolis',
#  'karratha',
#  'tabialan',
#  'washington',
#  'baruun-urt',
#  'tarragona',
#  'banda aceh',
#  'stykkisholmur',
#  'havre',
#  'vuktyl',
#  'carballo',
#  'veraval',
#  'zabid',
#  'timmins',
#  'lagoa',
#  'zhangye',
#  'puerto baquerizo moreno',
#  'denia',
#  'alugan',
#  'wukari',
#  'conceicao do araguaia',
#  'katherine',
#  'verkhniy baskunchak',
#  'mokhsogollokh',
#  'bairiki',
#  'nemuro',
#  'mount gambier',
#  'la plaine',
#  'srandakan',
#  'ulladulla',
#  'oshawa',
#  'asfi',
#  'zhenhai',
#  'san ramon',
#  'smoky lake',
#  'west wendover',
#  'port augusta',
#  'kaniama',
#  'san vicente',
#  'paita',
#  'luanda',
#  'mujiayingzi',
#  'porto novo',
#  'helong',
#  'smirnykh',
#  'krapivinskiy',
#  'axim',
#  'morro bay',
#  'gueret',
#  'sabang',
#  'kaeo',
#  'dondo',
#  'eenhana',
#  'cockburn town',
#  'oktyabrskiy',
#  'itaituba',
#  'mahaicony',
#  'shitanjing',
#  'savannah bight',
#  'general pico',
#  'mahebourg',
#  'namibe',
#  'blantyre',
#  'praia da vitoria',
#  'koboldo',
#  'manono',
#  'graaff-reinet',
#  'serik',
#  'pacifica',
#  'sisophon',
#  'bilibino',
#  'birin',
#  'hobyo',
#  'tigre',
#  'chapada dos guimaraes',
#  'ust-tsilma',
#  'manokwari',
#  'kalmunai',
#  'khasan',
#  'glace bay',
#  'chitrakonda',
#  'abu samrah',
#  'seoul',
#  'colares',
#  'trelew',
#  'jinchang',
#  'tahoua',
#  'dabakala',
#  'ipixuna',
#  'ust-nera',
#  'khash',
#  'bolshoye ignatovo',
#  'miyako',
#  'shenjiamen',
#  'novochernorechenskiy',
#  'fuerte olimpo',
#  'kumluca',
#  'port blair',
#  'itarema',
#  'harsin',
#  'auki',
#  'aguimes',
#  'batagay',
#  'krasnorechenskiy',
#  'hami',
#  'balikpapan',
#  'bolungarvik',
#  'urulga',
#  'marawi',
#  'yar-sale',
#  'kilindoni',
#  'mtwara',
#  'agadez',
#  'ambon',
#  'inverell',
#  'mingshui',
#  'meyungs',
#  'saint anthony',
#  'kenora',
#  'kieta',
#  'port shepstone',
#  'merritt',
#  'roald',
#  'zemio',
#  'grand-lahou',
#  'governador valadares',
#  'rio gallegos',
#  'constitucion',
#  'te anau',
#  'chokwe',
#  'balimo',
#  'kitui',
#  'phangnga',
#  'oriximina',
#  'hambantota',
#  'awbari',
#  'imeni poliny osipenko',
#  'catalina',
#  'hong gai',
#  'esna',
#  'mahibadhoo',
#  'sinnamary',
#  'singkang',
#  'krasnyy chikoy',
#  'yuzhno-kurilsk',
#  'tunduru',
#  'yaan',
#  'kankon',
#  'neiafu',
#  'bilma',
#  'berlevag',
#  'klamath falls',
#  'alyangula',
#  'zhigansk',
#  'jodhpur',
#  'andahuaylas',
#  'chake chake',
#  'gizo',
#  'abha',
#  'ubatuba',
#  'harer',
#  'hvammstangi',
#  'kigorobya',
#  'rakiv lis',
#  'lazarev',
#  'manta',
#  'athabasca',
#  'chibombo',
#  'goya',
#  'jacareacanga',
#  'aljezur',
#  'nhulunbuy',
#  'kamaishi',
#  'saint-augustin',
#  'touba',
#  'nogliki',
#  'gamba',
#  'half moon bay',
#  'tomatlan',
#  'los llanos de aridane',
#  'ballina',
#  'broome',
#  'dawei',
#  'aripuana',
#  'goure',
#  'sergeyevka',
#  'wonthaggi',
#  'smithers',
#  'rockhampton',
#  'turtas',
#  'puerto colombia',
#  'sur',
#  'namatanai',
#  'bossembele',
#  'jiazi',
#  'ulu-telyak',
#  'havelock',
#  'brenham',
#  'simbahan',
#  'arlit',
#  'lagos',
#  'one hundred mile house',
#  'litoral del san juan',
#  'sorong',
#  'asau',
#  'lima',
#  'ambodifototra',
#  'aksarka',
#  'stoyba',
#  'ciras',
#  'norton',
#  'phalodi',
#  'cambridge',
#  'tatvan',
#  'gien',
#  'svetlogorsk',
#  'ures',
#  'dumai',
#  'nurota',
#  'beian',
#  'dianopolis',
#  'cap malheureux',
#  'envira']

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

for i,city in enumerate(cities):
    
    city_url = url +"&q=" + city.replace(" ","+")
    print(f"Processing Record for : {city}")   
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record for : kahului
# Processing Record for : ostrovnoy
# Processing Record for : new norfolk
# Processing Record for : punta arenas
# Processing Record for : albany
# Processing Record for : labuhan
# Processing Record for : saldanha
# Processing Record for : rikitea
# Processing Record for : mataura
# Processing Record for : nuevo ideal
# Processing Record for : kaitangata
# Processing Record for : cape town
# Processing Record for : castro
# Processing Record for : codrington
# Processing Record for : kruisfontein
# Processing Record for : westport
# Processing Record for : hobart
# Processing Record for : hilo
# Processing Record for : san quintin
# Processing Record for : baran
# Processing Record for : burns lake
# Processing Record for : palabuhanratu
# City not found. Skipping...
# Processing Record for : tonj
# Processing Record for : talcahuano
# Processing Record for : bambous virieux
# Processing Record for : guerrero negro
# Processing Record for : vila franca do campo
# Processing Record for : ust-kuyga
# Processing Record for : butaritari
# Processing Record for : port elizabeth
# Processing Record for : jamestown
# Processing Record for : bredasdorp
# Processing Record for : severo-kurilsk
# Processing Record for : kapaa
# Processing Record for : puerto ayora
# Processing Record for : bethel
# Processing Record for : nkayi
# Processing Record for : biltine
# Processing Record for : shingu
# Processing Record for : saskylakh
# Processing Record for : bluff
# Processing Record for : grand river south east
# City not found. Skipping...
# Processing Record for : iqaluit
# Processing Record for : addis zemen
# City not found. Skipping...
# Processing Record for : inhambane
# Processing Record for : pevek
# Processing Record for : busselton
# Processing Record for : tekeli
# Processing Record for : chicama
# Processing Record for : airai
# Processing Record for : vaini
# Processing Record for : mozarlandia
# Processing Record for : verkhnechusovskiye gorodki
# Processing Record for : nikolskoye
# Processing Record for : matara
# Processing Record for : selfoss
# Processing Record for : fare
# Processing Record for : warqla
# City not found. Skipping...
# Processing Record for : xining
# Processing Record for : miraflores
# Processing Record for : ushuaia
# Processing Record for : saleaula
# City not found. Skipping...
# Processing Record for : chokurdakh
# Processing Record for : saint-leu
# Processing Record for : san cristobal
# Processing Record for : port alfred
# Processing Record for : taolanaro
# City not found. Skipping...
# Processing Record for : komsomolskiy
# Processing Record for : bara
# Processing Record for : alofi
# Processing Record for : baghdad
# Processing Record for : dali
# Processing Record for : batticaloa
# Processing Record for : loa janan
# Processing Record for : faanui
# Processing Record for : daru
# Processing Record for : wanaka
# Processing Record for : posadas
# Processing Record for : belushya guba
# City not found. Skipping...
# Processing Record for : amderma
# City not found. Skipping...
# Processing Record for : bollnas
# Processing Record for : arraial do cabo
# Processing Record for : aklavik
# Processing Record for : jumla
# Processing Record for : thompson
# Processing Record for : luancheng
# Processing Record for : narsaq
# Processing Record for : kingaroy
# Processing Record for : georgetown
# Processing Record for : portland
# Processing Record for : caravelas
# Processing Record for : tasiilaq
# Processing Record for : tuktoyaktuk
# Processing Record for : mago
# Processing Record for : taoudenni
# Processing Record for : nanchang
# Processing Record for : vaitupu
# City not found. Skipping...
# Processing Record for : vila velha
# Processing Record for : ombessa
# Processing Record for : chara
# Processing Record for : avarua
# Processing Record for : vestmanna
# Processing Record for : tucumcari
# Processing Record for : illoqqortoormiut
# City not found. Skipping...
# Processing Record for : segou
# Processing Record for : leningradskiy
# Processing Record for : pisco
# Processing Record for : tuatapere
# Processing Record for : provideniya
# Processing Record for : kodiak
# Processing Record for : qaanaaq
# Processing Record for : lyuban
# Processing Record for : cabo san lucas
# Processing Record for : petropavlovsk-kamchatskiy
# Processing Record for : luganville
# Processing Record for : college
# Processing Record for : saint-philippe
# Processing Record for : paradwip
# City not found. Skipping...
# Processing Record for : quatre cocos
# Processing Record for : atuona
# Processing Record for : iskateley
# Processing Record for : suntar
# Processing Record for : jardim
# Processing Record for : bamberg
# Processing Record for : owando
# Processing Record for : sentyabrskiy
# City not found. Skipping...
# Processing Record for : kamwenge
# Processing Record for : aswan
# Processing Record for : marcona
# City not found. Skipping...
# Processing Record for : nizhneyansk
# City not found. Skipping...
# Processing Record for : carnarvon
# Processing Record for : sakakah
# Processing Record for : port lincoln
# Processing Record for : mahajanga
# Processing Record for : tsihombe
# City not found. Skipping...
# Processing Record for : barrow
# Processing Record for : barentsburg
# City not found. Skipping...
# Processing Record for : brandon
# Processing Record for : namwala
# Processing Record for : henties bay
# Processing Record for : ribeira grande
# Processing Record for : balabac
# Processing Record for : rohru
# Processing Record for : monrovia
# Processing Record for : machilipatnam
# Processing Record for : vardo
# Processing Record for : khatanga
# Processing Record for : hermanus
# Processing Record for : americus
# Processing Record for : rocha
# Processing Record for : leshukonskoye
# Processing Record for : mpongwe
# Processing Record for : la rioja
# Processing Record for : viedma
# Processing Record for : loknya
# Processing Record for : kuche
# City not found. Skipping...
# Processing Record for : barkhan
# Processing Record for : northam
# Processing Record for : nanortalik
# Processing Record for : porterville
# Processing Record for : povenets
# Processing Record for : husavik
# Processing Record for : cayenne
# Processing Record for : tungor
# Processing Record for : fenoarivo
# Processing Record for : nome
# Processing Record for : marsabit
# Processing Record for : turukhansk
# Processing Record for : fort nelson
# Processing Record for : tabiauea
# City not found. Skipping...
# Processing Record for : rognan
# Processing Record for : vredendal
# Processing Record for : lebu
# Processing Record for : constantine
# Processing Record for : bourail
# Processing Record for : mar del plata
# Processing Record for : buraydah
# Processing Record for : ayolas
# Processing Record for : aksu
# Processing Record for : vaitape
# Processing Record for : maunabo
# Processing Record for : makoshyne
# Processing Record for : ahuimanu
# Processing Record for : ponta do sol
# Processing Record for : sambava
# Processing Record for : lasa
# Processing Record for : dubbo
# Processing Record for : surman
# Processing Record for : aykhal
# Processing Record for : sitio novo do tocantins
# Processing Record for : yellowknife
# Processing Record for : morant bay
# Processing Record for : upernavik
# Processing Record for : diu
# Processing Record for : norman wells
# Processing Record for : marsh harbour
# Processing Record for : santiago del estero
# Processing Record for : srednekolymsk
# Processing Record for : makung
# City not found. Skipping...
# Processing Record for : olafsvik
# Processing Record for : znamenskoye
# Processing Record for : rio grande
# Processing Record for : dudinka
# Processing Record for : sao joao da barra
# Processing Record for : hithadhoo
# Processing Record for : dunedin
# Processing Record for : coquimbo
# Processing Record for : saint simons
# Processing Record for : torbay
# Processing Record for : hofn
# Processing Record for : bengkulu
# Processing Record for : ha tinh
# Processing Record for : prince rupert
# Processing Record for : lavrentiya
# Processing Record for : angoram
# Processing Record for : daura
# Processing Record for : zapolyarnyy
# Processing Record for : sitka
# Processing Record for : bereda
# Processing Record for : isangel
# Processing Record for : souillac
# Processing Record for : formosa
# Processing Record for : leninsk
# Processing Record for : esperance
# Processing Record for : nioro
# Processing Record for : porto torres
# Processing Record for : ulverstone
# Processing Record for : zhurivka
# Processing Record for : rawson
# Processing Record for : geraldton
# Processing Record for : leh
# Processing Record for : belaya gora
# Processing Record for : alta floresta
# Processing Record for : brae
# Processing Record for : waingapu
# Processing Record for : krasnoarmeysk
# Processing Record for : toliary
# City not found. Skipping...
# Processing Record for : elverum
# Processing Record for : ancud
# Processing Record for : othonoi
# City not found. Skipping...
# Processing Record for : erice
# Processing Record for : andros town
# Processing Record for : palmer
# Processing Record for : saint george
# Processing Record for : tautira
# Processing Record for : kununurra
# Processing Record for : dimitrovgrad
# Processing Record for : saint-joseph
# Processing Record for : yatou
# Processing Record for : umzimvubu
# City not found. Skipping...
# Processing Record for : courtalam
# City not found. Skipping...
# Processing Record for : kavieng
# Processing Record for : tumannyy
# City not found. Skipping...
# Processing Record for : fairbanks
# Processing Record for : skalistyy
# City not found. Skipping...
# Processing Record for : batagay-alyta
# Processing Record for : nabire
# Processing Record for : coihaique
# Processing Record for : yantal
# Processing Record for : pangnirtung
# Processing Record for : inuvik
# Processing Record for : vestmannaeyjar
# Processing Record for : ngunguru
# Processing Record for : korla
# Processing Record for : mercedes
# Processing Record for : kyabram
# Processing Record for : blagoyevo
# Processing Record for : verkhnyaya inta
# Processing Record for : isabela
# Processing Record for : roscrea
# Processing Record for : chachapoyas
# Processing Record for : novyy yarychiv
# Processing Record for : ballinasloe
# Processing Record for : lewistown
# Processing Record for : samusu
# City not found. Skipping...
# Processing Record for : ciudad bolivar
# Processing Record for : bargal
# City not found. Skipping...
# Processing Record for : bartica
# Processing Record for : hervey bay
# Processing Record for : cidreira
# Processing Record for : manaure
# Processing Record for : scottsburgh
# City not found. Skipping...
# Processing Record for : eyl
# Processing Record for : dikson
# Processing Record for : muros
# Processing Record for : key west
# Processing Record for : atar
# Processing Record for : huarmey
# Processing Record for : savelugu
# Processing Record for : vanimo
# Processing Record for : sola
# Processing Record for : aporawan
# City not found. Skipping...
# Processing Record for : barstow
# Processing Record for : victoria
# Processing Record for : kapit
# Processing Record for : east london
# Processing Record for : izberbash
# Processing Record for : sechura
# Processing Record for : pacific grove
# Processing Record for : puerto escondido
# Processing Record for : kinkala
# Processing Record for : teeli
# Processing Record for : port hardy
# Processing Record for : cukai
# Processing Record for : presidente medici
# Processing Record for : ketchikan
# Processing Record for : tiksi
# Processing Record for : great bend
# Processing Record for : kachug
# Processing Record for : ozernovskiy
# Processing Record for : mys shmidta
# City not found. Skipping...
# Processing Record for : faya
# Processing Record for : halifax
# Processing Record for : sobolevo
# Processing Record for : chaohu
# Processing Record for : placido de castro
# Processing Record for : seara
# Processing Record for : bud
# Processing Record for : necochea
# Processing Record for : chuy
# Processing Record for : lompoc
# Processing Record for : shagonar
# Processing Record for : chany
# Processing Record for : kathu
# Processing Record for : san rafael
# Processing Record for : teluknaga
# Processing Record for : ansalta
# Processing Record for : khorixas
# Processing Record for : matagami
# Processing Record for : anadyr
# Processing Record for : ayan
# Processing Record for : nizwa
# Processing Record for : sao filipe
# Processing Record for : cangucu
# Processing Record for : gravelbourg
# Processing Record for : ngukurr
# City not found. Skipping...
# Processing Record for : grindavik
# Processing Record for : dibulla
# Processing Record for : concepcion
# Processing Record for : cherskiy
# Processing Record for : flinders
# Processing Record for : bagotville
# Processing Record for : grand centre
# City not found. Skipping...
# Processing Record for : naze
# Processing Record for : galiwinku
# City not found. Skipping...
# Processing Record for : port hedland
# Processing Record for : werda
# Processing Record for : luderitz
# Processing Record for : ranot
# Processing Record for : bonoua
# Processing Record for : yumen
# Processing Record for : nishihara
# Processing Record for : hammerfest
# Processing Record for : champerico
# Processing Record for : san patricio
# Processing Record for : iranshahr
# Processing Record for : dolores
# Processing Record for : kachiry
# Processing Record for : anastacio
# Processing Record for : tomball
# Processing Record for : ziduri
# Processing Record for : bontang
# Processing Record for : longyearbyen
# Processing Record for : payo
# Processing Record for : vao
# Processing Record for : east stroudsburg
# Processing Record for : saint-francois
# Processing Record for : kangaatsiaq
# Processing Record for : mnogovershinnyy
# Processing Record for : bonfim
# Processing Record for : masunga
# Processing Record for : jalu
# Processing Record for : barela
# Processing Record for : harper
# Processing Record for : samalaeulu
# City not found. Skipping...
# Processing Record for : fort saint john
# City not found. Skipping...
# Processing Record for : ca mau
# Processing Record for : gobabis
# Processing Record for : el faiyum
# City not found. Skipping...
# Processing Record for : tezu
# Processing Record for : louisbourg
# City not found. Skipping...
# Processing Record for : coahuayana
# Processing Record for : cabra
# Processing Record for : najran
# Processing Record for : sagua la grande
# Processing Record for : matozinhos
# Processing Record for : ulaanbaatar
# Processing Record for : humboldt
# Processing Record for : ginda
# Processing Record for : price
# Processing Record for : baza
# Processing Record for : sept-iles
# Processing Record for : beloha
# Processing Record for : lensk
# Processing Record for : flin flon
# Processing Record for : libohove
# Processing Record for : adrar
# Processing Record for : lorengau
# Processing Record for : juneau
# Processing Record for : clyde river
# Processing Record for : mana
# Processing Record for : zhuzhou
# Processing Record for : puro
# Processing Record for : honningsvag
# Processing Record for : antofagasta
# Processing Record for : port macquarie
# Processing Record for : kichera
# Processing Record for : hohhot
# Processing Record for : hasaki
# Processing Record for : awjilah
# Processing Record for : udachnyy
# Processing Record for : chifeng
# Processing Record for : turan
# Processing Record for : chiang klang
# Processing Record for : cajnice
# Processing Record for : mersing
# Processing Record for : nkan
# Processing Record for : burnie
# Processing Record for : svetlyy
# Processing Record for : darhan
# Processing Record for : kamenskoye
# City not found. Skipping...
# Processing Record for : maragogi
# Processing Record for : kontagora
# Processing Record for : upington
# Processing Record for : kabinda
# Processing Record for : eureka
# Processing Record for : tevaitoa
# Processing Record for : attawapiskat
# City not found. Skipping...
# Processing Record for : lowestoft
# Processing Record for : san carlos de bariloche
# Processing Record for : nyrob
# Processing Record for : port-gentil
# Processing Record for : buala
# Processing Record for : yanan
# City not found. Skipping...
# Processing Record for : ye
# City not found. Skipping...
# Processing Record for : yuancheng
# Processing Record for : ostrogozhsk
# Processing Record for : yendi
# Processing Record for : fortuna
# Processing Record for : zhangjiakou
# Processing Record for : haukipudas
# Processing Record for : bujaru
# Processing Record for : kulhudhuffushi
# Processing Record for : wahran
# City not found. Skipping...
# Processing Record for : san antonio
# Processing Record for : jurm
# Processing Record for : uhlove
# Processing Record for : igis
# Processing Record for : borgo san lorenzo
# Processing Record for : denpasar
# Processing Record for : mbandaka
# Processing Record for : puerto carreno
# Processing Record for : broken hill
# Processing Record for : barra do pirai
# Processing Record for : hamilton
# Processing Record for : venado tuerto
# Processing Record for : burgeo
# Processing Record for : tuban
# Processing Record for : los alamos
# Processing Record for : manakara
# Processing Record for : magrath
# Processing Record for : jaciara
# Processing Record for : la asuncion
# Processing Record for : hovd
# Processing Record for : laguna
# Processing Record for : puerto lempira
# Processing Record for : uvat
# Processing Record for : ponta delgada
# Processing Record for : wakkanai
# Processing Record for : samarai
# Processing Record for : bathsheba
# Processing Record for : omsukchan
# Processing Record for : berezna
# Processing Record for : bubaque
# Processing Record for : belawan
# Processing Record for : takoradi
# Processing Record for : nokha
# Processing Record for : raniganj
# Processing Record for : pokhara
# Processing Record for : voh
# Processing Record for : gorom-gorom
# Processing Record for : rawannawi
# City not found. Skipping...
# Processing Record for : chikoy
# City not found. Skipping...
# Processing Record for : sibolga
# Processing Record for : tamluk
# Processing Record for : skibbereen
# Processing Record for : figeac
# Processing Record for : cervo
# Processing Record for : rudbar
# Processing Record for : roma
# Processing Record for : hokitika
# Processing Record for : frederick
# Processing Record for : port hawkesbury
# Processing Record for : haines junction
# Processing Record for : lagunas
# Processing Record for : tasbuget
# City not found. Skipping...
# Processing Record for : saint marys
# Processing Record for : la estancia
# Processing Record for : opuwo
# Processing Record for : coruripe
# Processing Record for : nampula
# Processing Record for : maniitsoq
# Processing Record for : shache
# Processing Record for : beyneu
# Processing Record for : bacuit
# City not found. Skipping...
# Processing Record for : ranong
# Processing Record for : segamat
# Processing Record for : myanaung
# Processing Record for : tuzha
# Processing Record for : brigantine
# Processing Record for : rodez
# Processing Record for : muscat
# Processing Record for : wahiawa
# Processing Record for : caloundra
# Processing Record for : mareeba
# Processing Record for : rungata
# City not found. Skipping...
# Processing Record for : praia
# Processing Record for : alice springs
# Processing Record for : acapulco
# Processing Record for : rancho mirage
# Processing Record for : ordynskoye
# Processing Record for : jiddah
# City not found. Skipping...
# Processing Record for : san isidro
# Processing Record for : san narciso
# Processing Record for : kazalinsk
# City not found. Skipping...
# Processing Record for : meadow lake
# Processing Record for : kota kinabalu
# Processing Record for : ilebo
# Processing Record for : salalah
# Processing Record for : mocambique
# City not found. Skipping...
# Processing Record for : rio branco
# Processing Record for : bolkhov
# Processing Record for : kidal
# Processing Record for : korsakov
# Processing Record for : aflu
# City not found. Skipping...
# Processing Record for : knin
# Processing Record for : sao luis do quitunde
# Processing Record for : bay roberts
# Processing Record for : mayo
# Processing Record for : havoysund
# Processing Record for : itainopolis
# Processing Record for : karratha
# Processing Record for : tabialan
# City not found. Skipping...
# Processing Record for : washington
# Processing Record for : baruun-urt
# Processing Record for : tarragona
# Processing Record for : banda aceh
# Processing Record for : stykkisholmur
# Processing Record for : havre
# Processing Record for : vuktyl
# Processing Record for : carballo
# Processing Record for : veraval
# Processing Record for : zabid
# Processing Record for : timmins
# Processing Record for : lagoa
# Processing Record for : zhangye
# Processing Record for : puerto baquerizo moreno
# Processing Record for : denia
# Processing Record for : alugan
# Processing Record for : wukari
# Processing Record for : conceicao do araguaia
# Processing Record for : katherine
# Processing Record for : verkhniy baskunchak
# Processing Record for : mokhsogollokh
# Processing Record for : bairiki
# Processing Record for : nemuro
# Processing Record for : mount gambier
# Processing Record for : la plaine
# Processing Record for : srandakan
# Processing Record for : ulladulla
# Processing Record for : oshawa
# Processing Record for : asfi
# Processing Record for : zhenhai
# Processing Record for : san ramon
# Processing Record for : smoky lake
# Processing Record for : west wendover
# Processing Record for : port augusta
# Processing Record for : kaniama
# Processing Record for : san vicente
# Processing Record for : paita
# Processing Record for : luanda
# Processing Record for : mujiayingzi
# Processing Record for : porto novo
# Processing Record for : helong
# Processing Record for : smirnykh
# Processing Record for : krapivinskiy
# Processing Record for : axim
# Processing Record for : morro bay
# Processing Record for : gueret
# Processing Record for : sabang
# Processing Record for : kaeo
# Processing Record for : dondo
# Processing Record for : eenhana
# Processing Record for : cockburn town
# Processing Record for : oktyabrskiy
# Processing Record for : itaituba
# Processing Record for : mahaicony
# City not found. Skipping...
# Processing Record for : shitanjing
# Processing Record for : savannah bight
# Processing Record for : general pico
# Processing Record for : mahebourg
# Processing Record for : namibe
# Processing Record for : blantyre
# Processing Record for : praia da vitoria
# Processing Record for : koboldo
# City not found. Skipping...
# Processing Record for : manono
# Processing Record for : graaff-reinet
# Processing Record for : serik
# Processing Record for : pacifica
# Processing Record for : sisophon
# Processing Record for : bilibino
# Processing Record for : birin
# Processing Record for : hobyo
# Processing Record for : tigre
# Processing Record for : chapada dos guimaraes
# Processing Record for : ust-tsilma
# Processing Record for : manokwari
# Processing Record for : kalmunai
# Processing Record for : khasan
# Processing Record for : glace bay
# Processing Record for : chitrakonda
# Processing Record for : abu samrah
# Processing Record for : seoul
# Processing Record for : colares
# Processing Record for : trelew
# Processing Record for : jinchang
# Processing Record for : tahoua
# Processing Record for : dabakala
# Processing Record for : ipixuna
# Processing Record for : ust-nera
# Processing Record for : khash
# Processing Record for : bolshoye ignatovo
# City not found. Skipping...
# Processing Record for : miyako
# Processing Record for : shenjiamen
# Processing Record for : novochernorechenskiy
# Processing Record for : fuerte olimpo
# Processing Record for : kumluca
# Processing Record for : port blair
# Processing Record for : itarema
# Processing Record for : harsin
# Processing Record for : auki
# Processing Record for : aguimes
# Processing Record for : batagay
# Processing Record for : krasnorechenskiy
# Processing Record for : hami
# Processing Record for : balikpapan
# Processing Record for : bolungarvik
# City not found. Skipping...
# Processing Record for : urulga
# City not found. Skipping...
# Processing Record for : marawi
# Processing Record for : yar-sale
# Processing Record for : kilindoni
# Processing Record for : mtwara
# Processing Record for : agadez
# Processing Record for : ambon
# Processing Record for : inverell
# Processing Record for : mingshui
# Processing Record for : meyungs
# City not found. Skipping...
# Processing Record for : saint anthony
# Processing Record for : kenora
# Processing Record for : kieta
# Processing Record for : port shepstone
# Processing Record for : merritt
# Processing Record for : roald
# Processing Record for : zemio
# Processing Record for : grand-lahou
# Processing Record for : governador valadares
# Processing Record for : rio gallegos
# Processing Record for : constitucion
# Processing Record for : te anau
# Processing Record for : chokwe
# Processing Record for : balimo
# City not found. Skipping...
# Processing Record for : kitui
# Processing Record for : phangnga
# Processing Record for : oriximina
# Processing Record for : hambantota
# Processing Record for : awbari
# Processing Record for : imeni poliny osipenko
# Processing Record for : catalina
# Processing Record for : hong gai
# Processing Record for : esna
# Processing Record for : mahibadhoo
# Processing Record for : sinnamary
# Processing Record for : singkang
# Processing Record for : krasnyy chikoy
# Processing Record for : yuzhno-kurilsk
# Processing Record for : tunduru
# City not found. Skipping...
# Processing Record for : yaan
# Processing Record for : kankon
# Processing Record for : neiafu
# Processing Record for : bilma
# Processing Record for : berlevag
# Processing Record for : klamath falls
# Processing Record for : alyangula
# Processing Record for : zhigansk
# Processing Record for : jodhpur
# Processing Record for : andahuaylas
# Processing Record for : chake chake
# Processing Record for : gizo
# Processing Record for : abha
# Processing Record for : ubatuba
# Processing Record for : harer
# Processing Record for : hvammstangi
# City not found. Skipping...
# Processing Record for : kigorobya
# Processing Record for : rakiv lis
# Processing Record for : lazarev
# Processing Record for : manta
# Processing Record for : athabasca
# Processing Record for : chibombo
# Processing Record for : goya
# Processing Record for : jacareacanga
# Processing Record for : aljezur
# Processing Record for : nhulunbuy
# Processing Record for : kamaishi
# Processing Record for : saint-augustin
# Processing Record for : touba
# Processing Record for : nogliki
# Processing Record for : gamba
# Processing Record for : half moon bay
# Processing Record for : tomatlan
# Processing Record for : los llanos de aridane
# Processing Record for : ballina
# Processing Record for : broome
# Processing Record for : dawei
# Processing Record for : aripuana
# Processing Record for : goure
# Processing Record for : sergeyevka
# Processing Record for : wonthaggi
# Processing Record for : smithers
# Processing Record for : rockhampton
# Processing Record for : turtas
# Processing Record for : puerto colombia
# Processing Record for : sur
# Processing Record for : namatanai
# Processing Record for : bossembele
# City not found. Skipping...
# Processing Record for : jiazi
# Processing Record for : ulu-telyak
# Processing Record for : havelock
# Processing Record for : brenham
# Processing Record for : simbahan
# Processing Record for : arlit
# Processing Record for : lagos
# Processing Record for : one hundred mile house
# City not found. Skipping...
# Processing Record for : litoral del san juan
# City not found. Skipping...
# Processing Record for : sorong
# Processing Record for : asau
# Processing Record for : lima
# Processing Record for : ambodifototra
# City not found. Skipping...
# Processing Record for : aksarka
# Processing Record for : stoyba
# City not found. Skipping...
# Processing Record for : ciras
# City not found. Skipping...
# Processing Record for : norton
# Processing Record for : phalodi
# Processing Record for : cambridge
# Processing Record for : tatvan
# Processing Record for : gien
# Processing Record for : svetlogorsk
# Processing Record for : ures
# Processing Record for : dumai
# Processing Record for : nurota
# Processing Record for : beian
# Processing Record for : dianopolis
# City not found. Skipping...
# Processing Record for : cap malheureux
# Processing Record for : envira

# %%
city_data
# Out:
# [{'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 89.6,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 16.61,
#   'Humidity': 92,
#   'Cloudiness': 91,
#   'Wind Speed': 12.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 75,
#   'Humidity': 44,
#   'Cloudiness': 59,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 50,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 20.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 26.01,
#   'Humidity': 49,
#   'Cloudiness': 64,
#   'Wind Speed': 11.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 76.19,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 78.06,
#   'Humidity': 74,
#   'Cloudiness': 67,
#   'Wind Speed': 5.53,
#   'Current Description': 'light rain'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 62.01,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nuevo Ideal',
#   'Country': 'MX',
#   'Lat': 24.89,
#   'Lng': -105.07,
#   'Max Temp': 60.04,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 19.08,
#   'Current Description': 'clear sky'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 64.99,
#   'Humidity': 71,
#   'Cloudiness': 99,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 64,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 65.79,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 64.42,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 8.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 58.77,
#   'Humidity': 93,
#   'Cloudiness': 51,
#   'Wind Speed': 4.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Westport',
#   'Country': 'US',
#   'Lat': 41.14,
#   'Lng': -73.36,
#   'Max Temp': 32,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 75,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Current Description': 'light rain'},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Lat': 30.48,
#   'Lng': -115.95,
#   'Max Temp': 58.78,
#   'Humidity': 66,
#   'Cloudiness': 3,
#   'Wind Speed': 13.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Baran',
#   'Country': 'IN',
#   'Lat': 25.1,
#   'Lng': 76.52,
#   'Max Temp': 44.85,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 5.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Burns Lake',
#   'Country': 'CA',
#   'Lat': 54.23,
#   'Lng': -125.75,
#   'Max Temp': 19.4,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tonj',
#   'Country': 'SS',
#   'Lat': 7.27,
#   'Lng': 28.68,
#   'Max Temp': 74.68,
#   'Humidity': 31,
#   'Cloudiness': 4,
#   'Wind Speed': 2.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Talcahuano',
#   'Country': 'CL',
#   'Lat': -36.72,
#   'Lng': -73.12,
#   'Max Temp': 64.4,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 60.66,
#   'Humidity': 61,
#   'Cloudiness': 3,
#   'Wind Speed': 17.54,
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.72,
#   'Lng': -25.43,
#   'Max Temp': 51.8,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ust-Kuyga',
#   'Country': 'RU',
#   'Lat': 70.02,
#   'Lng': 135.6,
#   'Max Temp': -23.84,
#   'Humidity': 85,
#   'Cloudiness': 97,
#   'Wind Speed': 3.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 81.54,
#   'Humidity': 81,
#   'Cloudiness': 97,
#   'Wind Speed': 19.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 19,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 1.92,
#   'Current Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 26.22,
#   'Humidity': 89,
#   'Cloudiness': 87,
#   'Wind Speed': 18.32,
#   'Current Description': 'light snow'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 73,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 28.4,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Nkayi',
#   'Country': 'CG',
#   'Lat': -4.18,
#   'Lng': 13.29,
#   'Max Temp': 74.37,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Biltine',
#   'Country': 'TD',
#   'Lat': 14.53,
#   'Lng': 20.92,
#   'Max Temp': 70.45,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Shingu',
#   'Country': 'JP',
#   'Lat': 33.73,
#   'Lng': 135.98,
#   'Max Temp': 51.8,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 23.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': -23.69,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 12.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 62.01,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 5,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Current Description': 'light snow'},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.86,
#   'Lng': 35.38,
#   'Max Temp': 80.13,
#   'Humidity': 87,
#   'Cloudiness': 82,
#   'Wind Speed': 11.45,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': -10.97,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 75.99,
#   'Humidity': 60,
#   'Cloudiness': 19,
#   'Wind Speed': 3,
#   'Current Description': 'few clouds'},
#  {'City': 'Tekeli',
#   'Country': 'KZ',
#   'Lat': 44.83,
#   'Lng': 78.82,
#   'Max Temp': 16.3,
#   'Humidity': 76,
#   'Cloudiness': 71,
#   'Wind Speed': 8.32,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chicama',
#   'Country': 'PE',
#   'Lat': -7.84,
#   'Lng': -79.15,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'mist'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 68.88,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 0.94,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mozarlandia',
#   'Country': 'BR',
#   'Lat': -14.74,
#   'Lng': -50.57,
#   'Max Temp': 79.45,
#   'Humidity': 66,
#   'Cloudiness': 86,
#   'Wind Speed': 4.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Verkhnechusovskiye Gorodki',
#   'Country': 'RU',
#   'Lat': 58.17,
#   'Lng': 57.11,
#   'Max Temp': -13.95,
#   'Humidity': 88,
#   'Cloudiness': 15,
#   'Wind Speed': 2.71,
#   'Current Description': 'few clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 28.4,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 15.66,
#   'Current Description': 'light shower snow'},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Lat': 5.95,
#   'Lng': 80.54,
#   'Max Temp': 74.19,
#   'Humidity': 87,
#   'Cloudiness': 2,
#   'Wind Speed': 7.94,
#   'Current Description': 'clear sky'},
#  {'City': 'Selfoss',
#   'Country': 'IS',
#   'Lat': 63.93,
#   'Lng': -21,
#   'Max Temp': 24.01,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fare',
#   'Country': 'PF',
#   'Lat': -16.7,
#   'Lng': -151.02,
#   'Max Temp': 81.73,
#   'Humidity': 76,
#   'Cloudiness': 93,
#   'Wind Speed': 14.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Xining',
#   'Country': 'CN',
#   'Lat': 36.62,
#   'Lng': 101.77,
#   'Max Temp': 3.11,
#   'Humidity': 80,
#   'Cloudiness': 24,
#   'Wind Speed': 3.02,
#   'Current Description': 'few clouds'},
#  {'City': 'Miraflores',
#   'Country': 'MX',
#   'Lat': 19.22,
#   'Lng': -98.81,
#   'Max Temp': 66.2,
#   'Humidity': 24,
#   'Cloudiness': 5,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.8,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 26.4,
#   'Current Description': 'light rain'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': -34.35,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 7.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Leu',
#   'Country': 'RE',
#   'Lat': -21.15,
#   'Lng': 55.28,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 66,
#   'Humidity': 90,
#   'Cloudiness': 95,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Komsomolskiy',
#   'Country': 'UZ',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 28.4,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 0.49,
#   'Current Description': 'fog'},
#  {'City': 'Bara',
#   'Country': 'NG',
#   'Lat': 10.37,
#   'Lng': 10.73,
#   'Max Temp': 70.79,
#   'Humidity': 23,
#   'Cloudiness': 29,
#   'Wind Speed': 8.55,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 93,
#   'Wind Speed': 5.82,
#   'Current Description': 'light rain'},
#  {'City': 'Baghdad',
#   'Country': 'IQ',
#   'Lat': 33.34,
#   'Lng': 44.4,
#   'Max Temp': 44.6,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Dali',
#   'Country': 'CN',
#   'Lat': 25.7,
#   'Lng': 100.18,
#   'Max Temp': 36.9,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Batticaloa',
#   'Country': 'LK',
#   'Lat': 7.71,
#   'Lng': 81.69,
#   'Max Temp': 75.83,
#   'Humidity': 84,
#   'Cloudiness': 11,
#   'Wind Speed': 5.93,
#   'Current Description': 'few clouds'},
#  {'City': 'Loa Janan',
#   'Country': 'ID',
#   'Lat': -0.58,
#   'Lng': 117.09,
#   'Max Temp': 79.25,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 1.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 80.82,
#   'Humidity': 78,
#   'Cloudiness': 96,
#   'Wind Speed': 14.61,
#   'Current Description': 'light rain'},
#  {'City': 'Daru',
#   'Country': 'PG',
#   'Lat': -9.08,
#   'Lng': 143.21,
#   'Max Temp': 82.63,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.75,
#   'Current Description': 'moderate rain'},
#  {'City': 'Wanaka',
#   'Country': 'NZ',
#   'Lat': -44.7,
#   'Lng': 169.15,
#   'Max Temp': 66.7,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Posadas',
#   'Country': 'AR',
#   'Lat': -27.37,
#   'Lng': -55.9,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Bollnas',
#   'Country': 'SE',
#   'Lat': 61.35,
#   'Lng': 16.39,
#   'Max Temp': 36.36,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': -4,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jumla',
#   'Country': 'NP',
#   'Lat': 29.27,
#   'Lng': 82.18,
#   'Max Temp': 32.61,
#   'Humidity': 45,
#   'Cloudiness': 12,
#   'Wind Speed': 5.7,
#   'Current Description': 'few clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 3.2,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'light snow'},
#  {'City': 'Luancheng',
#   'Country': 'CN',
#   'Lat': 37.88,
#   'Lng': 114.65,
#   'Max Temp': 10.4,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 21.2,
#   'Humidity': 62,
#   'Cloudiness': 98,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kingaroy',
#   'Country': 'AU',
#   'Lat': -26.53,
#   'Lng': 151.83,
#   'Max Temp': 75,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 41,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 1.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 74.37,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 14,
#   'Humidity': 85,
#   'Cloudiness': 21,
#   'Wind Speed': 1.12,
#   'Current Description': 'few clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': -7.6,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mago',
#   'Country': 'RU',
#   'Lat': 53.25,
#   'Lng': 140.18,
#   'Max Temp': -27.22,
#   'Humidity': 82,
#   'Cloudiness': 5,
#   'Wind Speed': 1.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 70.05,
#   'Humidity': 34,
#   'Cloudiness': 26,
#   'Wind Speed': 4.9,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nanchang',
#   'Country': 'CN',
#   'Lat': 28.68,
#   'Lng': 115.88,
#   'Max Temp': 33.35,
#   'Humidity': 88,
#   'Cloudiness': 79,
#   'Wind Speed': 12.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Ombessa',
#   'Country': 'CM',
#   'Lat': 4.6,
#   'Lng': 11.26,
#   'Max Temp': 71.74,
#   'Humidity': 91,
#   'Cloudiness': 82,
#   'Wind Speed': 2.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chara',
#   'Country': 'RU',
#   'Lat': 56.91,
#   'Lng': 118.26,
#   'Max Temp': -17.18,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 4.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 47,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.16,
#   'Lng': -7.17,
#   'Max Temp': 35.6,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 19.46,
#   'Current Description': 'light snow'},
#  {'City': 'Tucumcari',
#   'Country': 'US',
#   'Lat': 35.17,
#   'Lng': -103.72,
#   'Max Temp': 48.2,
#   'Humidity': 39,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Segou',
#   'Country': 'ML',
#   'Lat': 13.43,
#   'Lng': -6.22,
#   'Max Temp': 72.63,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': -9.9,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 0.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 18.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 62.01,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 17.9,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 39.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Current Description': 'light rain'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 8.82,
#   'Humidity': 83,
#   'Cloudiness': 55,
#   'Wind Speed': 1.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lyuban',
#   'Country': 'BY',
#   'Lat': 52.8,
#   'Lng': 28,
#   'Max Temp': 34.93,
#   'Humidity': 89,
#   'Cloudiness': 3,
#   'Wind Speed': 8.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 71.01,
#   'Humidity': 64,
#   'Cloudiness': 5,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Country': 'RU',
#   'Lat': 53.05,
#   'Lng': 158.65,
#   'Max Temp': 8.6,
#   'Humidity': 65,
#   'Cloudiness': 76,
#   'Wind Speed': 6.71,
#   'Current Description': 'broken clouds'},
#  {'City': 'Luganville',
#   'Country': 'VU',
#   'Lat': -15.53,
#   'Lng': 167.17,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 14,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 2.86,
#   'Current Description': 'few clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Quatre Cocos',
#   'Country': 'MU',
#   'Lat': -20.21,
#   'Lng': 57.76,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 78.91,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 13.94,
#   'Current Description': 'clear sky'},
#  {'City': 'Iskateley',
#   'Country': 'RU',
#   'Lat': 67.68,
#   'Lng': 53.15,
#   'Max Temp': -24.65,
#   'Humidity': 84,
#   'Cloudiness': 10,
#   'Wind Speed': 6.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Suntar',
#   'Country': 'RU',
#   'Lat': 62.14,
#   'Lng': 117.63,
#   'Max Temp': -5.04,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 10.02,
#   'Current Description': 'light snow'},
#  {'City': 'Jardim',
#   'Country': 'BR',
#   'Lat': -21.48,
#   'Lng': -56.14,
#   'Max Temp': 75.45,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bamberg',
#   'Country': 'DE',
#   'Lat': 49.88,
#   'Lng': 10.89,
#   'Max Temp': 33.01,
#   'Humidity': 82,
#   'Cloudiness': 80,
#   'Wind Speed': 4.25,
#   'Current Description': 'broken clouds'},
#  {'City': 'Owando',
#   'Country': 'CG',
#   'Lat': -0.48,
#   'Lng': 15.9,
#   'Max Temp': 73.13,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kamwenge',
#   'Country': 'UG',
#   'Lat': 0.19,
#   'Lng': 30.45,
#   'Max Temp': 63.7,
#   'Humidity': 87,
#   'Cloudiness': 51,
#   'Wind Speed': 1.07,
#   'Current Description': 'broken clouds'},
#  {'City': 'Aswan',
#   'Country': 'EG',
#   'Lat': 24.09,
#   'Lng': 32.91,
#   'Max Temp': 60.91,
#   'Humidity': 50,
#   'Cloudiness': 26,
#   'Wind Speed': 7.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 36,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sakakah',
#   'Country': 'SA',
#   'Lat': 29.97,
#   'Lng': 40.21,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.73,
#   'Lng': 135.87,
#   'Max Temp': 65.43,
#   'Humidity': 72,
#   'Cloudiness': 84,
#   'Wind Speed': 11.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mahajanga',
#   'Country': 'MG',
#   'Lat': -15.72,
#   'Lng': 46.32,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'light rain'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': -7.6,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Brandon',
#   'Country': 'US',
#   'Lat': 27.94,
#   'Lng': -82.29,
#   'Max Temp': 66.99,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Namwala',
#   'Country': 'ZM',
#   'Lat': -15.75,
#   'Lng': 26.44,
#   'Max Temp': 68.45,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.6,
#   'Current Description': 'light rain'},
#  {'City': 'Henties Bay',
#   'Country': 'NA',
#   'Lat': -22.12,
#   'Lng': 14.28,
#   'Max Temp': 66,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 57.9,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Balabac',
#   'Country': 'PH',
#   'Lat': 7.99,
#   'Lng': 117.06,
#   'Max Temp': 82.17,
#   'Humidity': 76,
#   'Cloudiness': 37,
#   'Wind Speed': 2.77,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rohru',
#   'Country': 'IN',
#   'Lat': 31.22,
#   'Lng': 77.75,
#   'Max Temp': 31.62,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 5.26,
#   'Current Description': 'clear sky'},
#  {'City': 'Monrovia',
#   'Country': 'LR',
#   'Lat': 6.3,
#   'Lng': -10.8,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 5.95,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Machilipatnam',
#   'Country': 'IN',
#   'Lat': 16.17,
#   'Lng': 81.13,
#   'Max Temp': 69.78,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 9.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 33.57,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 14.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': -31.13,
#   'Humidity': 84,
#   'Cloudiness': 74,
#   'Wind Speed': 8.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 62.01,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Americus',
#   'Country': 'US',
#   'Lat': 32.07,
#   'Lng': -84.23,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 5.88,
#   'Current Description': 'clear sky'},
#  {'City': 'Rocha',
#   'Country': 'UY',
#   'Lat': -34.48,
#   'Lng': -54.33,
#   'Max Temp': 68.56,
#   'Humidity': 78,
#   'Cloudiness': 22,
#   'Wind Speed': 7.92,
#   'Current Description': 'few clouds'},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Lat': 64.9,
#   'Lng': 45.76,
#   'Max Temp': 5.56,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mpongwe',
#   'Country': 'ZM',
#   'Lat': -13.51,
#   'Lng': 28.16,
#   'Max Temp': 63.27,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'La Rioja',
#   'Country': 'ES',
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 39.99,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Viedma',
#   'Country': 'AR',
#   'Lat': -40.81,
#   'Lng': -63,
#   'Max Temp': 82.99,
#   'Humidity': 27,
#   'Cloudiness': 44,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Loknya',
#   'Country': 'RU',
#   'Lat': 56.83,
#   'Lng': 30.15,
#   'Max Temp': 37.38,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barkhan',
#   'Country': 'PK',
#   'Lat': 29.9,
#   'Lng': 69.53,
#   'Max Temp': 36.84,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 2.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Northam',
#   'Country': 'GB',
#   'Lat': 51.03,
#   'Lng': -4.22,
#   'Max Temp': 42.01,
#   'Humidity': 86,
#   'Cloudiness': 28,
#   'Wind Speed': 5.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 25.12,
#   'Humidity': 90,
#   'Cloudiness': 93,
#   'Wind Speed': 5.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porterville',
#   'Country': 'US',
#   'Lat': 36.07,
#   'Lng': -119.02,
#   'Max Temp': 53.6,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Povenets',
#   'Country': 'RU',
#   'Lat': 62.85,
#   'Lng': 34.83,
#   'Max Temp': 20.28,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 16.2,
#   'Current Description': 'light snow'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.04,
#   'Lng': -17.34,
#   'Max Temp': 19.4,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Tungor',
#   'Country': 'RU',
#   'Lat': 53.38,
#   'Lng': 142.96,
#   'Max Temp': -20.16,
#   'Humidity': 84,
#   'Cloudiness': 74,
#   'Wind Speed': 10.51,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fenoarivo',
#   'Country': 'MG',
#   'Lat': -18.93,
#   'Lng': 47.44,
#   'Max Temp': 64.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'light intensity drizzle'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 33.8,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Current Description': 'light snow'},
#  {'City': 'Marsabit',
#   'Country': 'KE',
#   'Lat': 2.33,
#   'Lng': 37.99,
#   'Max Temp': 68.99,
#   'Humidity': 58,
#   'Cloudiness': 66,
#   'Wind Speed': 7.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Turukhansk',
#   'Country': 'RU',
#   'Lat': 65.82,
#   'Lng': 87.98,
#   'Max Temp': -18.15,
#   'Humidity': 79,
#   'Cloudiness': 80,
#   'Wind Speed': 12.57,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fort Nelson',
#   'Country': 'CA',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': 5,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rognan',
#   'Country': 'NO',
#   'Lat': 67.1,
#   'Lng': 15.39,
#   'Max Temp': 37.4,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 17.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Vredendal',
#   'Country': 'ZA',
#   'Lat': -31.67,
#   'Lng': 18.5,
#   'Max Temp': 57.11,
#   'Humidity': 88,
#   'Cloudiness': 10,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 58.17,
#   'Humidity': 79,
#   'Cloudiness': 12,
#   'Wind Speed': 10.85,
#   'Current Description': 'few clouds'},
#  {'City': 'Constantine',
#   'Country': 'DZ',
#   'Lat': 36.37,
#   'Lng': 6.61,
#   'Max Temp': 42.8,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bourail',
#   'Country': 'NC',
#   'Lat': -21.57,
#   'Lng': 165.48,
#   'Max Temp': 84.22,
#   'Humidity': 65,
#   'Cloudiness': 36,
#   'Wind Speed': 8.08,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 72,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.33,
#   'Lng': 43.98,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ayolas',
#   'Country': 'PY',
#   'Lat': -27.4,
#   'Lng': -56.9,
#   'Max Temp': 82.69,
#   'Humidity': 50,
#   'Cloudiness': 14,
#   'Wind Speed': 4.25,
#   'Current Description': 'few clouds'},
#  {'City': 'Aksu',
#   'Country': 'CN',
#   'Lat': 41.12,
#   'Lng': 80.26,
#   'Max Temp': 14.22,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 3.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Vaitape',
#   'Country': 'PF',
#   'Lat': -16.52,
#   'Lng': -151.75,
#   'Max Temp': 81.66,
#   'Humidity': 77,
#   'Cloudiness': 95,
#   'Wind Speed': 14.45,
#   'Current Description': 'light rain'},
#  {'City': 'Maunabo',
#   'Country': 'PR',
#   'Lat': 18.01,
#   'Lng': -65.9,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 61,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Makoshyne',
#   'Country': 'UA',
#   'Lat': 51.46,
#   'Lng': 32.34,
#   'Max Temp': 35.17,
#   'Humidity': 98,
#   'Cloudiness': 94,
#   'Wind Speed': 7.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ahuimanu',
#   'Country': 'US',
#   'Lat': 21.44,
#   'Lng': -157.84,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 60.8,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sambava',
#   'Country': 'MG',
#   'Lat': -14.27,
#   'Lng': 50.17,
#   'Max Temp': 76.71,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 9.1,
#   'Current Description': 'light rain'},
#  {'City': 'Lasa',
#   'Country': 'IT',
#   'Lat': 46.62,
#   'Lng': 10.7,
#   'Max Temp': 30.99,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dubbo',
#   'Country': 'AU',
#   'Lat': -32.25,
#   'Lng': 148.62,
#   'Max Temp': 77,
#   'Humidity': 61,
#   'Cloudiness': 3,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Surman',
#   'Country': 'LY',
#   'Lat': 32.76,
#   'Lng': 12.57,
#   'Max Temp': 56.39,
#   'Humidity': 39,
#   'Cloudiness': 30,
#   'Wind Speed': 11.52,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aykhal',
#   'Country': 'RU',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -14.8,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 8.95,
#   'Current Description': 'light snow'},
#  {'City': 'Sitio Novo Do Tocantins',
#   'Country': 'BR',
#   'Lat': -5.52,
#   'Lng': -47.46,
#   'Max Temp': 77.7,
#   'Humidity': 76,
#   'Cloudiness': 31,
#   'Wind Speed': 3.02,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': -4,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Description': 'light snow'},
#  {'City': 'Morant Bay',
#   'Country': 'JM',
#   'Lat': 17.88,
#   'Lng': -76.41,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 15.42,
#   'Humidity': 81,
#   'Cloudiness': 23,
#   'Wind Speed': 8.7,
#   'Current Description': 'few clouds'},
#  {'City': 'Diu',
#   'Country': 'IN',
#   'Lat': 20.71,
#   'Lng': 70.98,
#   'Max Temp': 61.7,
#   'Humidity': 32,
#   'Cloudiness': 50,
#   'Wind Speed': 13.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': -5.8,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Marsh Harbour',
#   'Country': 'BS',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 71.15,
#   'Humidity': 73,
#   'Cloudiness': 31,
#   'Wind Speed': 26.84,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Santiago Del Estero',
#   'Country': 'AR',
#   'Lat': -27.8,
#   'Lng': -64.26,
#   'Max Temp': 87.01,
#   'Humidity': 64,
#   'Cloudiness': 4,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.68,
#   'Max Temp': -40.22,
#   'Humidity': 81,
#   'Cloudiness': 74,
#   'Wind Speed': 2.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 33.91,
#   'Humidity': 88,
#   'Cloudiness': 80,
#   'Wind Speed': 6.02,
#   'Current Description': 'broken clouds'},
#  {'City': 'Znamenskoye',
#   'Country': 'RU',
#   'Lat': 57.13,
#   'Lng': 73.83,
#   'Max Temp': -9.83,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.03,
#   'Lng': -52.1,
#   'Max Temp': 75,
#   'Humidity': 89,
#   'Cloudiness': 11,
#   'Wind Speed': 1.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Dudinka',
#   'Country': 'RU',
#   'Lat': 69.41,
#   'Lng': 86.18,
#   'Max Temp': -11.2,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 76.06,
#   'Humidity': 84,
#   'Cloudiness': 79,
#   'Wind Speed': 18.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 81.95,
#   'Humidity': 77,
#   'Cloudiness': 93,
#   'Wind Speed': 8.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.87,
#   'Lng': 170.5,
#   'Max Temp': 59.29,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 64.4,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint Simons',
#   'Country': 'US',
#   'Lat': 31.14,
#   'Lng': -81.39,
#   'Max Temp': 55.99,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 36,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'light rain'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 24.71,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 15.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 76.73,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind Speed': 4.52,
#   'Current Description': 'light rain'},
#  {'City': 'Ha Tinh',
#   'Country': 'VN',
#   'Lat': 18.33,
#   'Lng': 105.9,
#   'Max Temp': 64.8,
#   'Humidity': 87,
#   'Cloudiness': 70,
#   'Wind Speed': 15.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.32,
#   'Lng': -130.32,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Current Description': 'light rain'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 21.02,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 10.67,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Angoram',
#   'Country': 'PG',
#   'Lat': -4.06,
#   'Lng': 144.07,
#   'Max Temp': 79.72,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 1.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Daura',
#   'Country': 'NG',
#   'Lat': 11.55,
#   'Lng': 11.41,
#   'Max Temp': 66.81,
#   'Humidity': 25,
#   'Cloudiness': 3,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Zapolyarnyy',
#   'Country': 'RU',
#   'Lat': 69.42,
#   'Lng': 30.81,
#   'Max Temp': 24.8,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 44.6,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Current Description': 'light rain'},
#  {'City': 'Bereda',
#   'Country': 'ES',
#   'Lat': 43.27,
#   'Lng': -7.54,
#   'Max Temp': 37.99,
#   'Humidity': 100,
#   'Cloudiness': 84,
#   'Wind Speed': 5.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 84.2,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Formosa',
#   'Country': 'AR',
#   'Lat': -26.18,
#   'Lng': -58.18,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Leninsk',
#   'Country': 'RU',
#   'Lat': 48.71,
#   'Lng': 45.2,
#   'Max Temp': 19.4,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 8.95,
#   'Current Description': 'mist'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 68,
#   'Humidity': 60,
#   'Cloudiness': 41,
#   'Wind Speed': 14.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nioro',
#   'Country': 'GM',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 78.33,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Porto Torres',
#   'Country': 'IT',
#   'Lat': 40.84,
#   'Lng': 8.4,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Ulverstone',
#   'Country': 'AU',
#   'Lat': -41.15,
#   'Lng': 146.17,
#   'Max Temp': 70,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 6.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Zhurivka',
#   'Country': 'UA',
#   'Lat': 50.5,
#   'Lng': 31.78,
#   'Max Temp': 37.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.71,
#   'Current Description': 'fog'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3,
#   'Lng': -65.1,
#   'Max Temp': 72.19,
#   'Humidity': 43,
#   'Cloudiness': 38,
#   'Wind Speed': 19.08,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Leh',
#   'Country': 'IN',
#   'Lat': 34.17,
#   'Lng': 77.58,
#   'Max Temp': -3.37,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 2.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Belaya Gora',
#   'Country': 'RU',
#   'Lat': 68.53,
#   'Lng': 146.42,
#   'Max Temp': -36.54,
#   'Humidity': 83,
#   'Cloudiness': 46,
#   'Wind Speed': 2.68,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alta Floresta',
#   'Country': 'BR',
#   'Lat': -9.88,
#   'Lng': -56.09,
#   'Max Temp': 71.08,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Current Description': 'moderate rain'},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.4,
#   'Lng': -1.35,
#   'Max Temp': 39.2,
#   'Humidity': 77,
#   'Cloudiness': 4,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Waingapu',
#   'Country': 'ID',
#   'Lat': -9.66,
#   'Lng': 120.26,
#   'Max Temp': 81.41,
#   'Humidity': 69,
#   'Cloudiness': 91,
#   'Wind Speed': 5.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Krasnoarmeysk',
#   'Country': 'RU',
#   'Lat': 51.02,
#   'Lng': 45.7,
#   'Max Temp': 6.03,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Elverum',
#   'Country': 'NO',
#   'Lat': 60.88,
#   'Lng': 11.56,
#   'Max Temp': 35.01,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'light snow'},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 53.01,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Erice',
#   'Country': 'IT',
#   'Lat': 38.04,
#   'Lng': 12.59,
#   'Max Temp': 57.99,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain'},
#  {'City': 'Andros Town',
#   'Country': 'BS',
#   'Lat': 24.7,
#   'Lng': -77.77,
#   'Max Temp': 73.4,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 27,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 46.4,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Tautira',
#   'Country': 'PF',
#   'Lat': -17.73,
#   'Lng': -149.15,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'shower rain'},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Lat': -15.77,
#   'Lng': 128.73,
#   'Max Temp': 84.2,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dimitrovgrad',
#   'Country': 'RU',
#   'Lat': 54.21,
#   'Lng': 49.62,
#   'Max Temp': 14,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 8.95,
#   'Current Description': 'light snow'},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Lat': -21.37,
#   'Lng': 55.62,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Yatou',
#   'Country': 'CN',
#   'Lat': 37.15,
#   'Lng': 122.38,
#   'Max Temp': 15.96,
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 20.09,
#   'Current Description': 'light snow'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 84.67,
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 4.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fairbanks',
#   'Country': 'US',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 14,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 2.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Batagay-Alyta',
#   'Country': 'RU',
#   'Lat': 67.8,
#   'Lng': 130.41,
#   'Max Temp': -16.6,
#   'Humidity': 80,
#   'Cloudiness': 94,
#   'Wind Speed': 5.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Lat': -3.37,
#   'Lng': 135.48,
#   'Max Temp': 78.67,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coihaique',
#   'Country': 'CL',
#   'Lat': -45.58,
#   'Lng': -72.07,
#   'Max Temp': 51.8,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds'},
#  {'City': 'Yantal',
#   'Country': 'RU',
#   'Lat': 56.85,
#   'Lng': 105.25,
#   'Max Temp': -22.65,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 2.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.15,
#   'Lng': -65.71,
#   'Max Temp': 12.2,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Current Description': 'light snow'},
#  {'City': 'Inuvik',
#   'Country': 'CA',
#   'Lat': 68.35,
#   'Lng': -133.72,
#   'Max Temp': -9.4,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 32.47,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 14.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ngunguru',
#   'Country': 'NZ',
#   'Lat': -35.62,
#   'Lng': 174.5,
#   'Max Temp': 69.94,
#   'Humidity': 51,
#   'Cloudiness': 3,
#   'Wind Speed': 4.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Korla',
#   'Country': 'CN',
#   'Lat': 41.76,
#   'Lng': 86.15,
#   'Max Temp': 15.49,
#   'Humidity': 88,
#   'Cloudiness': 6,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Mercedes',
#   'Country': 'AR',
#   'Lat': -34.65,
#   'Lng': -59.43,
#   'Max Temp': 84,
#   'Humidity': 63,
#   'Cloudiness': 23,
#   'Wind Speed': 9.69,
#   'Current Description': 'few clouds'},
#  {'City': 'Kyabram',
#   'Country': 'AU',
#   'Lat': -36.32,
#   'Lng': 145.05,
#   'Max Temp': 78.01,
#   'Humidity': 41,
#   'Cloudiness': 51,
#   'Wind Speed': 4.65,
#   'Current Description': 'broken clouds'},
#  {'City': 'Blagoyevo',
#   'Country': 'RU',
#   'Lat': 63.37,
#   'Lng': 47.92,
#   'Max Temp': 0.72,
#   'Humidity': 90,
#   'Cloudiness': 91,
#   'Wind Speed': 4.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Verkhnyaya Inta',
#   'Country': 'RU',
#   'Lat': 65.98,
#   'Lng': 60.31,
#   'Max Temp': -25.94,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 1.45,
#   'Current Description': 'clear sky'},
#  {'City': 'Isabela',
#   'Country': 'PH',
#   'Lat': 6.71,
#   'Lng': 121.97,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Roscrea',
#   'Country': 'IE',
# ...
#   'Lat': 8.45,
#   'Lng': 98.53,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Oriximina',
#   'Country': 'BR',
#   'Lat': -1.77,
#   'Lng': -55.87,
#   'Max Temp': 76.12,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds'},
#  {'City': 'Awbari',
#   'Country': 'LY',
#   'Lat': 26.59,
#   'Lng': 12.78,
#   'Max Temp': 53.96,
#   'Humidity': 39,
#   'Cloudiness': 12,
#   'Wind Speed': 9.1,
#   'Current Description': 'few clouds'},
#  {'City': 'Imeni Poliny Osipenko',
#   'Country': 'RU',
#   'Lat': 52.42,
#   'Lng': 136.49,
#   'Max Temp': -22.67,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 1.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Catalina',
#   'Country': 'US',
#   'Lat': 32.51,
#   'Lng': -110.92,
#   'Max Temp': 53.01,
#   'Humidity': 53,
#   'Cloudiness': 57,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hong Gai',
#   'Country': 'VN',
#   'Lat': 20.96,
#   'Lng': 107.09,
#   'Max Temp': 62.6,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Esna',
#   'Country': 'EG',
#   'Lat': 25.29,
#   'Lng': 32.55,
#   'Max Temp': 59,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 5.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Mahibadhoo',
#   'Country': 'MV',
#   'Lat': 3.78,
#   'Lng': 72.97,
#   'Max Temp': 82.06,
#   'Humidity': 73,
#   'Cloudiness': 62,
#   'Wind Speed': 6.64,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 77.97,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 7.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Singkang',
#   'Country': 'MY',
#   'Lat': 2.1,
#   'Lng': 102.8,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 3,
#   'Current Description': 'few clouds'},
#  {'City': 'Krasnyy Chikoy',
#   'Country': 'RU',
#   'Lat': 50.36,
#   'Lng': 108.75,
#   'Max Temp': -20.69,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 3.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yuzhno-Kurilsk',
#   'Country': 'RU',
#   'Lat': 44.03,
#   'Lng': 145.86,
#   'Max Temp': 21.65,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 7.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yaan',
#   'Country': 'NG',
#   'Lat': 7.38,
#   'Lng': 8.57,
#   'Max Temp': 77.27,
#   'Humidity': 28,
#   'Cloudiness': 7,
#   'Wind Speed': 1.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Kankon',
#   'Country': 'IN',
#   'Lat': 15.02,
#   'Lng': 74.02,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 34,
#   'Wind Speed': 5.82,
#   'Current Description': 'haze'},
#  {'City': 'Neiafu',
#   'Country': 'TO',
#   'Lat': -18.65,
#   'Lng': -173.98,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bilma',
#   'Country': 'NE',
#   'Lat': 18.69,
#   'Lng': 12.92,
#   'Max Temp': 60.04,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 31.35,
#   'Humidity': 95,
#   'Cloudiness': 97,
#   'Wind Speed': 15.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Klamath Falls',
#   'Country': 'US',
#   'Lat': 42.22,
#   'Lng': -121.78,
#   'Max Temp': 33.8,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Alyangula',
#   'Country': 'AU',
#   'Lat': -13.85,
#   'Lng': 136.42,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zhigansk',
#   'Country': 'RU',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': -5.06,
#   'Humidity': 89,
#   'Cloudiness': 95,
#   'Wind Speed': 22.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jodhpur',
#   'Country': 'IN',
#   'Lat': 26.29,
#   'Lng': 73.03,
#   'Max Temp': 45.43,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 9.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Andahuaylas',
#   'Country': 'PE',
#   'Lat': -13.66,
#   'Lng': -73.39,
#   'Max Temp': 56.52,
#   'Humidity': 73,
#   'Cloudiness': 91,
#   'Wind Speed': 2.46,
#   'Current Description': 'moderate rain'},
#  {'City': 'Chake Chake',
#   'Country': 'TZ',
#   'Lat': -5.25,
#   'Lng': 39.77,
#   'Max Temp': 78.66,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gizo',
#   'Country': 'SB',
#   'Lat': -8.1,
#   'Lng': 156.84,
#   'Max Temp': 80.76,
#   'Humidity': 81,
#   'Cloudiness': 92,
#   'Wind Speed': 11.65,
#   'Current Description': 'moderate rain'},
#  {'City': 'Abha',
#   'Country': 'SA',
#   'Lat': 18.22,
#   'Lng': 42.51,
#   'Max Temp': 55.4,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Ubatuba',
#   'Country': 'BR',
#   'Lat': -23.43,
#   'Lng': -45.07,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Harer',
#   'Country': 'ET',
#   'Lat': 9.31,
#   'Lng': 42.13,
#   'Max Temp': 57.96,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 3.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Kigorobya',
#   'Country': 'UG',
#   'Lat': 1.62,
#   'Lng': 31.31,
#   'Max Temp': 72.36,
#   'Humidity': 65,
#   'Cloudiness': 42,
#   'Wind Speed': 2.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rakiv Lis',
#   'Country': 'UA',
#   'Lat': 51.62,
#   'Lng': 24.92,
#   'Max Temp': 40.55,
#   'Humidity': 78,
#   'Cloudiness': 16,
#   'Wind Speed': 12.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Lazarev',
#   'Country': 'RU',
#   'Lat': 52.23,
#   'Lng': 141.51,
#   'Max Temp': -16.35,
#   'Humidity': 82,
#   'Cloudiness': 56,
#   'Wind Speed': 4.59,
#   'Current Description': 'broken clouds'},
#  {'City': 'Manta',
#   'Country': 'EC',
#   'Lat': -0.95,
#   'Lng': -80.73,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Athabasca',
#   'Country': 'CA',
#   'Lat': 54.72,
#   'Lng': -113.29,
#   'Max Temp': 14,
#   'Humidity': 78,
#   'Cloudiness': 36,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chibombo',
#   'Country': 'ZM',
#   'Lat': -14.66,
#   'Lng': 28.07,
#   'Max Temp': 65.68,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Goya',
#   'Country': 'AR',
#   'Lat': -29.14,
#   'Lng': -59.26,
#   'Max Temp': 84.52,
#   'Humidity': 49,
#   'Cloudiness': 31,
#   'Wind Speed': 6.6,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jacareacanga',
#   'Country': 'BR',
#   'Lat': -6.22,
#   'Lng': -57.75,
#   'Max Temp': 71.94,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.42,
#   'Current Description': 'light rain'},
#  {'City': 'Aljezur',
#   'Country': 'PT',
#   'Lat': 37.32,
#   'Lng': -8.8,
#   'Max Temp': 45,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Nhulunbuy',
#   'Country': 'AU',
#   'Lat': -12.23,
#   'Lng': 136.77,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kamaishi',
#   'Country': 'JP',
#   'Lat': 39.27,
#   'Lng': 141.88,
#   'Max Temp': 30.2,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Current Description': 'light shower snow'},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 36.1,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 16.6,
#   'Current Description': 'light rain'},
#  {'City': 'Touba',
#   'Country': 'CI',
#   'Lat': 8.28,
#   'Lng': -7.68,
#   'Max Temp': 72.81,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 1.72,
#   'Current Description': 'clear sky'},
#  {'City': 'Nogliki',
#   'Country': 'RU',
#   'Lat': 51.83,
#   'Lng': 143.17,
#   'Max Temp': -10.7,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 10.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gamba',
#   'Country': 'GA',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 76.5,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'moderate rain'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.46,
#   'Lng': -122.43,
#   'Max Temp': 59,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Tomatlan',
#   'Country': 'MX',
#   'Lat': 19.93,
#   'Lng': -105.25,
#   'Max Temp': 73.45,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 62.6,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Ballina',
#   'Country': 'AU',
#   'Lat': -28.87,
#   'Lng': 153.57,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Broome',
#   'Country': 'US',
#   'Lat': 42.25,
#   'Lng': -75.83,
#   'Max Temp': 24.01,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Dawei',
#   'Country': 'MM',
#   'Lat': 14.08,
#   'Lng': 98.2,
#   'Max Temp': 73.06,
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 3.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aripuana',
#   'Country': 'BR',
#   'Lat': -9.17,
#   'Lng': -60.63,
#   'Max Temp': 73.26,
#   'Humidity': 91,
#   'Cloudiness': 84,
#   'Wind Speed': 0.47,
#   'Current Description': 'light rain'},
#  {'City': 'Goure',
#   'Country': 'NE',
#   'Lat': 13.98,
#   'Lng': 10.27,
#   'Max Temp': 68,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Sergeyevka',
#   'Country': 'KZ',
#   'Lat': 53.88,
#   'Lng': 67.42,
#   'Max Temp': -18.54,
#   'Humidity': 86,
#   'Cloudiness': 13,
#   'Wind Speed': 7.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Wonthaggi',
#   'Country': 'AU',
#   'Lat': -38.6,
#   'Lng': 145.59,
#   'Max Temp': 70,
#   'Humidity': 53,
#   'Cloudiness': 24,
#   'Wind Speed': 8.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Smithers',
#   'Country': 'CA',
#   'Lat': 54.78,
#   'Lng': -127.17,
#   'Max Temp': 21.2,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'light snow'},
#  {'City': 'Rockhampton',
#   'Country': 'AU',
#   'Lat': -23.38,
#   'Lng': 150.5,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Current Description': 'moderate rain'},
#  {'City': 'Turtas',
#   'Country': 'RU',
#   'Lat': 58.94,
#   'Lng': 69.13,
#   'Max Temp': -10.25,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Colombia',
#   'Country': 'CO',
#   'Lat': 10.99,
#   'Lng': -74.95,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.57,
#   'Lng': 59.53,
#   'Max Temp': 66.74,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 6.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Namatanai',
#   'Country': 'PG',
#   'Lat': -3.67,
#   'Lng': 152.43,
#   'Max Temp': 83.88,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 2.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jiazi',
#   'Country': 'CN',
#   'Lat': 22.88,
#   'Lng': 116.07,
#   'Max Temp': 54.18,
#   'Humidity': 60,
#   'Cloudiness': 13,
#   'Wind Speed': 23.76,
#   'Current Description': 'few clouds'},
#  {'City': 'Ulu-Telyak',
#   'Country': 'RU',
#   'Lat': 54.91,
#   'Lng': 56.97,
#   'Max Temp': -8.05,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Havelock',
#   'Country': 'US',
#   'Lat': 34.88,
#   'Lng': -76.9,
#   'Max Temp': 44.6,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Brenham',
#   'Country': 'US',
#   'Lat': 30.17,
#   'Lng': -96.4,
#   'Max Temp': 69.8,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Simbahan',
#   'Country': 'PH',
#   'Lat': 6.3,
#   'Lng': 120.58,
#   'Max Temp': 82.6,
#   'Humidity': 81,
#   'Cloudiness': 78,
#   'Wind Speed': 7.16,
#   'Current Description': 'broken clouds'},
#  {'City': 'Arlit',
#   'Country': 'NE',
#   'Lat': 18.74,
#   'Lng': 7.39,
#   'Max Temp': 64.85,
#   'Humidity': 24,
#   'Cloudiness': 12,
#   'Wind Speed': 6.33,
#   'Current Description': 'few clouds'},
#  {'City': 'Lagos',
#   'Country': 'NG',
#   'Lat': 6.58,
#   'Lng': 3.75,
#   'Max Temp': 77.99,
#   'Humidity': 86,
#   'Cloudiness': 45,
#   'Wind Speed': 4.27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Lat': -0.88,
#   'Lng': 131.25,
#   'Max Temp': 83.03,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 0.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Max Temp': 39,
#   'Humidity': 66,
#   'Cloudiness': 79,
#   'Wind Speed': 4.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lima',
#   'Country': 'PE',
#   'Lat': -12.04,
#   'Lng': -77.03,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Description': 'broken clouds'},
#  {'City': 'Aksarka',
#   'Country': 'RU',
#   'Lat': 66.56,
#   'Lng': 67.8,
#   'Max Temp': -17.21,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 11.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Norton',
#   'Country': 'ZW',
#   'Lat': -17.88,
#   'Lng': 30.7,
#   'Max Temp': 66.99,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Phalodi',
#   'Country': 'IN',
#   'Lat': 27.13,
#   'Lng': 72.37,
#   'Max Temp': 46.11,
#   'Humidity': 51,
#   'Cloudiness': 10,
#   'Wind Speed': 6.73,
#   'Current Description': 'clear sky'},
#  {'City': 'Cambridge',
#   'Country': 'CA',
#   'Lat': 43.36,
#   'Lng': -80.31,
#   'Max Temp': 21.99,
#   'Humidity': 92,
#   'Cloudiness': 1,
#   'Wind Speed': 3.94,
#   'Current Description': 'clear sky'},
#  {'City': 'Tatvan',
#   'Country': 'TR',
#   'Lat': 38.51,
#   'Lng': 42.28,
#   'Max Temp': 28.44,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 4.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Gien',
#   'Country': 'FR',
#   'Lat': 47.69,
#   'Lng': 2.63,
#   'Max Temp': 39,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Svetlogorsk',
#   'Country': 'BY',
#   'Lat': 52.63,
#   'Lng': 29.73,
#   'Max Temp': 33.48,
#   'Humidity': 93,
#   'Cloudiness': 39,
#   'Wind Speed': 7.16,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ures',
#   'Country': 'MX',
#   'Lat': 29.43,
#   'Lng': -110.4,
#   'Max Temp': 60.01,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Dumai',
#   'Country': 'ID',
#   'Lat': 1.68,
#   'Lng': 101.45,
#   'Max Temp': 73.92,
#   'Humidity': 95,
#   'Cloudiness': 86,
#   'Wind Speed': 0.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nurota',
#   'Country': 'UZ',
#   'Lat': 40.56,
#   'Lng': 65.69,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Description': 'mist'},
#  {'City': 'Beian',
#   'Country': 'NO',
#   'Lat': 63.66,
#   'Lng': 9.57,
#   'Max Temp': 41,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.98,
#   'Lng': 57.61,
#   'Max Temp': 75,
#   'Humidity': 81,
#   'Cloudiness': 3,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Envira',
#   'Country': 'BR',
#   'Lat': -7.3,
#   'Lng': -70.22,
#   'Max Temp': 73.53,
#   'Humidity': 97,
#   'Cloudiness': 88,
#   'Wind Speed': 2.33,
#   'Current Description': 'overcast clouds'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kahului      US  20.89 -156.47     89.60        46          40
# 1         Ostrovnoy      RU  68.05   39.51     16.61        92          91
# 2       New Norfolk      AU -42.78  147.06     75.00        44          59
# 3      Punta Arenas      CL -53.15  -70.92     50.00        57           0
# 4            Albany      US  42.60  -73.97     26.01        49          64
# ..              ...     ...    ...     ...       ...       ...         ...
# 690           Dumai      ID   1.68  101.45     73.92        95          86
# 691          Nurota      UZ  40.56   65.69     26.60        86           0
# 692           Beian      NO  63.66    9.57     41.00        65           0
# 693  Cap Malheureux      MU -19.98   57.61     75.00        81           3
# 694          Envira      BR  -7.30  -70.22     73.53        97          88
#
#      Wind Speed Current Description
# 0         16.11    scattered clouds
# 1         12.66     overcast clouds
# 2          1.99       broken clouds
# 3         20.80           clear sky
# 4         11.30       broken clouds
# ..          ...                 ...
# 690        0.56     overcast clouds
# 691        9.17                mist
# 692       14.99           clear sky
# 693        5.01           clear sky
# 694        2.33     overcast clouds
#
# [695 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
